# %% [markdown]
# # Selecting Data: loc(), iloc[]

# %% [raw]
# loc()
# - label based so we have to specify rows and columns based on their index/row and column LBAELS (names)
#
#     Value: df.loc['label']
#     List: df.loc[['label_one', 'label_two']]
#     Slicing: df.loc['label_one':'label_two']
#
#         -in slicing the stop element IS included
#
# iloc[]
# - integer position based so we have to specify rows and columns by their INTEGER POSITION VALUE (index)
#
#     Value: df.iloc[0]
#     List: df.iloc[[0,1]]
#     Slicing: df.iloc[0:2]
#
#         -in slicing the stop element IS NOT included

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('csv files/players_20.csv')
# df

# set index
df.set_index('short_name', inplace=True)

# new index becomes short_name column
# df

# select columns
df = df[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality","club"]]
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# Neymar Jr                175         68      Brazil
# J. Oblak                 188         87    Slovenia
# E. Hazard                175         74     Belgium
# ...                      ...        ...         ...
# Shao Shuai               186         79    China PR
# Xiao Mingjie             177         66    China PR
# Zhang Wei                186         75    China PR
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# J. Oblak                         Atlético Madrid
# E. Hazard                            Real Madrid
# ...                                          ...
# Shao Shuai                      Beijing Renhe FC
# Xiao Mingjie                    Shanghai SIPG FC
# Zhang Wei                 Hebei China Fortune FC
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %% [markdown]
# # 1 loc()

# %% [markdown]
# ## 1.1 Selecting with a single value

# %% [raw]
# Syntax:
#
# loc[row_label,column_label]

# %%
# get all data on L. Messi
df.loc['L. Messi']
# Out:
# long_name      Lionel Andrés Messi Cuccittini
# age                                        32
# dob                                1987-06-24
# height_cm                                 170
# weight_kg                                  72
# nationality                         Argentina
# club                             FC Barcelona
# Name: L. Messi, dtype: object

# %%
# get the height of L. Messi
df.loc['L. Messi', 'height_cm']
# Out:
# 170

# %%
# get the height of Cristiano Ronaldo
df.loc['Cristiano Ronaldo', 'height_cm']
# Out:
# 187

# %%
# get all rows inside the 'height_cm' column
df.loc[:, 'height_cm']

'''
: (colon) is a special symbol that selects all element inside a row or column
'''
# Out:
# '\n: (colon) is a special symbol that selects all element inside a row or column\n'

# %%
# get all the columns that correspond to the index 'L. Messi'
df.loc['L. Messi', :]

# same result as df.loc['L. Messi']
# Out:
# long_name      Lionel Andrés Messi Cuccittini
# age                                        32
# dob                                1987-06-24
# height_cm                                 170
# weight_kg                                  72
# nationality                         Argentina
# club                             FC Barcelona
# Name: L. Messi, dtype: object

# %% [markdown]
# ## 1.2 Selecting with a list of values

# %%
# get all data about Messi and Ronaldo
df.loc[['L. Messi', 'Cristiano Ronaldo']]
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality          club
# short_name
# L. Messi                 170         72   Argentina  FC Barcelona
# Cristiano Ronaldo        187         83    Portugal      Juventus

# %%
# get the height of Messi and Ronaldo
df.loc[['L. Messi', 'Cristiano Ronaldo'], 'height_cm']
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Name: height_cm, dtype: int64

# %%
# get height and weight of Messi
df.loc['L. Messi', ['height_cm', 'weight_kg']]
# Out:
# height_cm    170
# weight_kg     72
# Name: L. Messi, dtype: object

# %%
# get the height and weight of Messi and Ronaldo
df.loc[['L. Messi', 'Cristiano Ronaldo'], ['height_cm', 'weight_kg']]
# Out:
#                    height_cm  weight_kg
# short_name
# L. Messi                 170         72
# Cristiano Ronaldo        187         83

# %% [markdown]
# ## 1.3 Selecting a range of data with a slice

# %% [raw]
# start:stop:step (usual Python slices include both star and stop)

# %%
# slice column labels
players = ['L. Messi', 'Cristiano Ronaldo']
df.loc[players, 'age':'club']
# Out:
#                    age         dob  height_cm  weight_kg nationality  \
# short_name
# L. Messi            32  1987-06-24        170         72   Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
#
#                            club
# short_name
# L. Messi           FC Barcelona
# Cristiano Ronaldo      Juventus

# %%
# slice index labels
columns = ['age', 'dob', 'height_cm', 'weight_kg']

#get top1 and top10 player
df.loc[df.index[:10], columns]
# or 
df.loc['L. Messi':'M. Salah', columns]


# df.index[:10] gets first 10 index elements
# Out:
#                    age         dob  height_cm  weight_kg
# short_name
# L. Messi            32  1987-06-24        170         72
# Cristiano Ronaldo   34  1985-02-05        187         83
# Neymar Jr           27  1992-02-05        175         68
# J. Oblak            26  1993-01-07        188         87
# E. Hazard           28  1991-01-07        175         74
# K. De Bruyne        28  1991-06-28        181         70
# M. ter Stegen       27  1992-04-30        187         85
# V. van Dijk         27  1991-07-08        193         92
# L. Modrić           33  1985-09-09        172         66
# M. Salah            27  1992-06-15        175         71

# %% [markdown]
# ## 1.4 Selecting with conditions

# %%
# one condition: select player with height above 180cm
columns = ['age', 'dob', 'height_cm', 'weight_kg']

df.loc[ df['height_cm']>180, columns]
# Out:
#                    age         dob  height_cm  weight_kg
# short_name
# Cristiano Ronaldo   34  1985-02-05        187         83
# J. Oblak            26  1993-01-07        188         87
# K. De Bruyne        28  1991-06-28        181         70
# M. ter Stegen       27  1992-04-30        187         85
# V. van Dijk         27  1991-07-08        193         92
# ...                ...         ...        ...        ...
# P. Martin           20  1999-01-05        188         84
# Shao Shuai          22  1997-03-10        186         79
# Zhang Wei           19  2000-05-16        186         75
# Wang Haijian        18  2000-08-02        185         74
# Pan Ximing          26  1993-01-11        182         78
#
# [9744 rows x 4 columns]

# %%
# multiple conditions: heigt above 180cm and from Argentina
df.loc[ (df['height_cm']>180) & (df['nationality'] == 'Argentina') , :]
# Out:
#                                   long_name  age         dob  height_cm  \
# short_name
# M. Icardi       Mauro Emanuel Icardi Rivero   26  1993-02-19        181
# G. Higuaín          Gonzalo Gerardo Higuaín   31  1987-12-10        186
# E. Garay             Ezequiel Marcelo Garay   32  1986-10-10        189
# N. Otamendi         Nicolás Hernán Otamendi   31  1988-02-12        183
# G. Rulli                     Gerónimo Rulli   27  1992-05-20        189
# ...                                     ...  ...         ...        ...
# T. Durso                        Tomás Durso   20  1999-02-26        185
# J. Hass                        Joaquín Hass   21  1998-03-27        186
# R. Ferrario                 Rafael Ferrario   19  2000-04-30        186
# L. Finochietto          Leandro Finochietto   22  1997-04-25        186
# N. Forastiero            Nicolás Forastiero   20  1998-07-16        182
#
#                 weight_kg nationality                         club
# short_name
# M. Icardi              75   Argentina                        Inter
# G. Higuaín             89   Argentina                     Juventus
# E. Garay               90   Argentina                  Valencia CF
# N. Otamendi            81   Argentina              Manchester City
# G. Rulli               84   Argentina              Montpellier HSC
# ...                   ...         ...                          ...
# T. Durso               80   Argentina  Gimnasia y Esgrima La Plata
# J. Hass                88   Argentina          Club Atlético Colón
# R. Ferrario            76   Argentina        Club Atlético Huracán
# L. Finochietto         77   Argentina           Argentinos Juniors
# N. Forastiero          79   Argentina           Argentinos Juniors
#
# [350 rows x 7 columns]

# %% [markdown]
# # 2  iloc[]

# %% [raw]
# Syntax:
#
# df.iloc[row_position, column_position]
#
# Everything is basically the same a loc() except you use index positions and
# when slicing the 'stop' is not included -> start:stop:step.
#
# iloc[] also cannot accept a boolean series but can accept a boolean list.
# We have to use the list() fuction to convert a series into a boolean list.

# %%
df = pd.read_csv('csv files/players_20.csv')
# df

# new index becomes short_name column
# df

# select columns
df = df[["long_name", "short_name", "age", "dob", "height_cm", "weight_kg", "nationality","club"]]
df
# Out:
#                                  long_name         short_name  age  \
# 0           Lionel Andrés Messi Cuccittini           L. Messi   32
# 1      Cristiano Ronaldo dos Santos Aveiro  Cristiano Ronaldo   34
# 2            Neymar da Silva Santos Junior          Neymar Jr   27
# 3                                Jan Oblak           J. Oblak   26
# 4                              Eden Hazard          E. Hazard   28
# ...                                    ...                ...  ...
# 18273                                   邵帅         Shao Shuai   22
# 18274                         Mingjie Xiao       Xiao Mingjie   22
# 18275                                   张威          Zhang Wei   19
# 18276                                  汪海健       Wang Haijian   18
# 18277                                  潘喜明         Pan Ximing   26
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# 2      1992-02-05        175         68      Brazil
# 3      1993-01-07        188         87    Slovenia
# 4      1991-01-07        175         74     Belgium
# ...           ...        ...        ...         ...
# 18273  1997-03-10        186         79    China PR
# 18274  1997-01-01        177         66    China PR
# 18275  2000-05-16        186         75    China PR
# 18276  2000-08-02        185         74    China PR
# 18277  1993-01-11        182         78    China PR
#
#                                 club
# 0                       FC Barcelona
# 1                           Juventus
# 2                Paris Saint-Germain
# 3                    Atlético Madrid
# 4                        Real Madrid
# ...                              ...
# 18273               Beijing Renhe FC
# 18274               Shanghai SIPG FC
# 18275         Hebei China Fortune FC
# 18276  Shanghai Greenland Shenhua FC
# 18277         Hebei China Fortune FC
#
# [18278 rows x 8 columns]

# %% [markdown]
# ## 2.1 Selecting a range of data with a slice (1.3 but with iloc[])

# %%
# slice column labels
df.iloc[0:2, 0:3]
# Out:
#                              long_name         short_name  age
# 0       Lionel Andrés Messi Cuccittini           L. Messi   32
# 1  Cristiano Ronaldo dos Santos Aveiro  Cristiano Ronaldo   34

# %% [markdown]
# ## 2.2 Selecting with conditions (1.4 but with iloc[])

# %% [raw]
# We have to use the list() fuction to convert a series into a boolean list.

# %%
# one condition: select player with ehgih above 180cm

df.iloc[ list(df['height_cm']>180), 2:6]
# Out:
#        age         dob  height_cm  weight_kg
# 1       34  1985-02-05        187         83
# 3       26  1993-01-07        188         87
# 5       28  1991-06-28        181         70
# 6       27  1992-04-30        187         85
# 7       27  1991-07-08        193         92
# ...    ...         ...        ...        ...
# 18272   20  1999-01-05        188         84
# 18273   22  1997-03-10        186         79
# 18275   19  2000-05-16        186         75
# 18276   18  2000-08-02        185         74
# 18277   26  1993-01-11        182         78
#
# [9744 rows x 4 columns]

# %%
# multiple conditions: heigt above 180cm and from Argentina
df.iloc[ list((df['height_cm']>180) & (df['nationality'] == 'Argentina')) , :]
# Out:
#                          long_name      short_name  age         dob  \
# 93     Mauro Emanuel Icardi Rivero       M. Icardi   26  1993-02-19
# 98         Gonzalo Gerardo Higuaín      G. Higuaín   31  1987-12-10
# 210         Ezequiel Marcelo Garay        E. Garay   32  1986-10-10
# 224        Nicolás Hernán Otamendi     N. Otamendi   31  1988-02-12
# 342                 Gerónimo Rulli        G. Rulli   27  1992-05-20
# ...                            ...             ...  ...         ...
# 17412                  Tomás Durso        T. Durso   20  1999-02-26
# 17526                 Joaquín Hass         J. Hass   21  1998-03-27
# 17657              Rafael Ferrario     R. Ferrario   19  2000-04-30
# 17712          Leandro Finochietto  L. Finochietto   22  1997-04-25
# 17922           Nicolás Forastiero   N. Forastiero   20  1998-07-16
#
#        height_cm  weight_kg nationality                         club
# 93           181         75   Argentina                        Inter
# 98           186         89   Argentina                     Juventus
# 210          189         90   Argentina                  Valencia CF
# 224          183         81   Argentina              Manchester City
# 342          189         84   Argentina              Montpellier HSC
# ...          ...        ...         ...                          ...
# 17412        185         80   Argentina  Gimnasia y Esgrima La Plata
# 17526        186         88   Argentina          Club Atlético Colón
# 17657        186         76   Argentina        Club Atlético Huracán
# 17712        186         77   Argentina           Argentinos Juniors
# 17922        182         79   Argentina           Argentinos Juniors
#
# [350 rows x 8 columns]

# %% [markdown]
# # 3 Setting a New Value

# %%
df = pd.read_csv('csv files/players_20.csv')

# set index
df.set_index('short_name', inplace=True)

# select columns
df = df[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality","club"]]

# %% [markdown]
# ## 3.1 Set value to one cell

# %%
# update L. Messi height
df.loc["L. Messi", 'height_cm'] = 175
df.loc["L. Messi", 'height_cm']
# Out:
# 175

# %% [markdown]
# ## 3.2 Set value to entire column

# %%
# set height of all players to 190
df.loc[:, 'height_cm'] = 190
df.loc[:, 'height_cm']
# Out:
# short_name
# L. Messi             190
# Cristiano Ronaldo    190
# Neymar Jr            190
# J. Oblak             190
# E. Hazard            190
#                     ...
# Shao Shuai           190
# Xiao Mingjie         190
# Zhang Wei            190
# Wang Haijian         190
# Pan Ximing           190
# Name: height_cm, Length: 18278, dtype: int64

# %% [markdown]
# ## 3.3 Set value to entire row

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 190         72   Argentina
# Cristiano Ronaldo        190         83    Portugal
# Neymar Jr                190         68      Brazil
# J. Oblak                 190         87    Slovenia
# E. Hazard                190         74     Belgium
# ...                      ...        ...         ...
# Shao Shuai               190         79    China PR
# Xiao Mingjie             190         66    China PR
# Zhang Wei                190         75    China PR
# Wang Haijian             190         74    China PR
# Pan Ximing               190         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# J. Oblak                         Atlético Madrid
# E. Hazard                            Real Madrid
# ...                                          ...
# Shao Shuai                      Beijing Renhe FC
# Xiao Mingjie                    Shanghai SIPG FC
# Zhang Wei                 Hebei China Fortune FC
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
# get all columns that correspond to player ranked last in FIFA

'''
negative index (-1) got the last player by index
'''

df.iloc[-1, :]
# Out:
# long_name                         潘喜明
# age                                26
# dob                        1993-01-11
# height_cm                         190
# weight_kg                          78
# nationality                  China PR
# club           Hebei China Fortune FC
# Name: Pan Ximing, dtype: object

# %%
df.iloc[-1, :] = np.nan
df.iloc[-1, :]
# Out:
# long_name      NaN
# age            NaN
# dob            NaN
# height_cm      NaN
# weight_kg      NaN
# nationality    NaN
# club           NaN
# Name: Pan Ximing, dtype: object

# %% [markdown]
# ## 3.4 Set value to multiple cells

# %%
# set value for all items matching the list of labels
df.loc[['L. Messi', 'Cristiano Ronaldo'], 'height_cm'] = 175
df.loc[['L. Messi', 'Cristiano Ronaldo'], 'height_cm']
# Out:
# short_name
# L. Messi             175.0
# Cristiano Ronaldo    175.0
# Name: height_cm, dtype: float64

# %% [markdown]
# ## 3.5 Set value for rows matching a condition

# %%
# set value for rows matching a condition
columns = ['age', 'dob', 'height_cm', 'weight_kg']
df.loc[df['height_cm'] > 180, columns] = 0
df
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   0.0           0
# J. Oblak                                     Jan Oblak   0.0           0
# E. Hazard                                  Eden Hazard   0.0           0
# ...                                                ...   ...         ...
# Shao Shuai                                          邵帅   0.0           0
# Xiao Mingjie                              Mingjie Xiao   0.0           0
# Zhang Wei                                           张威   0.0           0
# Wang Haijian                                       汪海健   0.0           0
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi               175.0       72.0   Argentina
# Cristiano Ronaldo      175.0       83.0    Portugal
# Neymar Jr                0.0        0.0      Brazil
# J. Oblak                 0.0        0.0    Slovenia
# E. Hazard                0.0        0.0     Belgium
# ...                      ...        ...         ...
# Shao Shuai               0.0        0.0    China PR
# Xiao Mingjie             0.0        0.0    China PR
# Zhang Wei                0.0        0.0    China PR
# Wang Haijian             0.0        0.0    China PR
# Pan Ximing               NaN        NaN         NaN
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# J. Oblak                         Atlético Madrid
# E. Hazard                            Real Madrid
# ...                                          ...
# Shao Shuai                      Beijing Renhe FC
# Xiao Mingjie                    Shanghai SIPG FC
# Zhang Wei                 Hebei China Fortune FC
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                                   NaN
#
# [18278 rows x 7 columns]

# %% [markdown]
# # 4 Drop Rows or Columns: drop()

# %%
df = pd.read_csv('csv files/players_20.csv')

# set index
df.set_index('short_name', inplace=True)

# select columns
df = df[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality","club"]]

# %% [markdown]
# ## 4.1 Drop Rows

# %%
# drop one row

# axis parameter method
'''
axis paremeter lets drop() knows if its a row or column. 
0 represents rows and 1 represents columns
'''
df.drop('L. Messi', axis=0)

#index parameter method
df.drop(index=['L. Messi'])
#df
# Out:
#                                              long_name  age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# K. De Bruyne                           Kevin De Bruyne   28  1991-06-28
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# Cristiano Ronaldo        187         83    Portugal
# Neymar Jr                175         68      Brazil
# J. Oblak                 188         87    Slovenia
# E. Hazard                175         74     Belgium
# K. De Bruyne             181         70     Belgium
# ...                      ...        ...         ...
# Shao Shuai               186         79    China PR
# Xiao Mingjie             177         66    China PR
# Zhang Wei                186         75    China PR
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# J. Oblak                         Atlético Madrid
# E. Hazard                            Real Madrid
# K. De Bruyne                     Manchester City
# ...                                          ...
# Shao Shuai                      Beijing Renhe FC
# Xiao Mingjie                    Shanghai SIPG FC
# Zhang Wei                 Hebei China Fortune FC
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18277 rows x 7 columns]

# %%
# drop two or more rows and update data (inpalce=True)
df.drop(index=['L. Messi', 'Cristiano Ronaldo'], inplace=True)
df
# Out:
#                                    long_name  age         dob  height_cm  \
# short_name
# Neymar Jr      Neymar da Silva Santos Junior   27  1992-02-05        175
# J. Oblak                           Jan Oblak   26  1993-01-07        188
# E. Hazard                        Eden Hazard   28  1991-01-07        175
# K. De Bruyne                 Kevin De Bruyne   28  1991-06-28        181
# M. ter Stegen          Marc-André ter Stegen   27  1992-04-30        187
# ...                                      ...  ...         ...        ...
# Shao Shuai                                邵帅   22  1997-03-10        186
# Xiao Mingjie                    Mingjie Xiao   22  1997-01-01        177
# Zhang Wei                                 张威   19  2000-05-16        186
# Wang Haijian                             汪海健   18  2000-08-02        185
# Pan Ximing                               潘喜明   26  1993-01-11        182
#
#                weight_kg nationality                           club
# short_name
# Neymar Jr             68      Brazil            Paris Saint-Germain
# J. Oblak              87    Slovenia                Atlético Madrid
# E. Hazard             74     Belgium                    Real Madrid
# K. De Bruyne          70     Belgium                Manchester City
# M. ter Stegen         85     Germany                   FC Barcelona
# ...                  ...         ...                            ...
# Shao Shuai            79    China PR               Beijing Renhe FC
# Xiao Mingjie          66    China PR               Shanghai SIPG FC
# Zhang Wei             75    China PR         Hebei China Fortune FC
# Wang Haijian          74    China PR  Shanghai Greenland Shenhua FC
# Pan Ximing            78    China PR         Hebei China Fortune FC
#
# [18276 rows x 7 columns]

# %% [markdown]
# ## 4.2 Drop Columns

# %%
df = pd.read_csv('csv files/players_20.csv')

# set index
df.set_index('short_name', inplace=True)

# select columns
df = df[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality","club"]]

# %%
# drop one column

# axis parameter
df.drop('long_name', axis=1)

# columns parameter
df.drop(columns=['long_name'])
# Out:
#                    age         dob  height_cm  weight_kg nationality  \
# short_name
# L. Messi            32  1987-06-24        170         72   Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
# Neymar Jr           27  1992-02-05        175         68      Brazil
# J. Oblak            26  1993-01-07        188         87    Slovenia
# E. Hazard           28  1991-01-07        175         74     Belgium
# ...                ...         ...        ...        ...         ...
# Shao Shuai          22  1997-03-10        186         79    China PR
# Xiao Mingjie        22  1997-01-01        177         66    China PR
# Zhang Wei           19  2000-05-16        186         75    China PR
# Wang Haijian        18  2000-08-02        185         74    China PR
# Pan Ximing          26  1993-01-11        182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# J. Oblak                         Atlético Madrid
# E. Hazard                            Real Madrid
# ...                                          ...
# Shao Shuai                      Beijing Renhe FC
# Xiao Mingjie                    Shanghai SIPG FC
# Zhang Wei                 Hebei China Fortune FC
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 6 columns]

# %%
# drop column(s) by position/index (drop last and second to last column) and update dataframe
df.drop(columns=df.columns[[-1, -2]], inplace=True)


# or
df.drop(columns=['age', 'height_cm'], inplace=True)

df
# Out:
#                                              long_name         dob  weight_kg
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  1987-06-24         72
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  1985-02-05         83
# Neymar Jr                Neymar da Silva Santos Junior  1992-02-05         68
# J. Oblak                                     Jan Oblak  1993-01-07         87
# E. Hazard                                  Eden Hazard  1991-01-07         74
# ...                                                ...         ...        ...
# Shao Shuai                                          邵帅  1997-03-10         79
# Xiao Mingjie                              Mingjie Xiao  1997-01-01         66
# Zhang Wei                                           张威  2000-05-16         75
# Wang Haijian                                       汪海健  2000-08-02         74
# Pan Ximing                                         潘喜明  1993-01-11         78
#
# [18278 rows x 3 columns]

# %% [markdown]
# # 5 Create Random Samples: sample()

# %%
df = pd.read_csv('csv files/players_20.csv')
df.set_index('short_name', inplace=True)
df = df[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality","club"]]

# %%
# extract 10 random elements from the "nationality column"
'''
random_state parameter is a way to "freeze" the randomness
'''

df['nationality'].sample(10, random_state=99)
# Out:
# short_name
# R. Alvarado               Mexico
# Qiao Wei                China PR
# E. Paredes                 Chile
# K. Stoyanov             Bulgaria
# M. Chudý                Slovakia
# D. Sundaram                India
# R. Gagliardini             Italy
# G. Debeljuh              Croatia
# Kim Seung Yong    Korea Republic
# M. Hansen                Denmark
# Name: nationality, dtype: object

# %%
# extract random 20% sameple of the dataframe
df.sample(frac=0.2)
# Out:
#                                          long_name  age         dob  \
# short_name
# Kim Min Hyeok                              김민혁 金珉赫   27  1992-02-27
# L. Mai                              Lars Lukas Mai   19  2000-03-31
# T. Kainz                              Tobias Kainz   26  1992-10-31
# C. Jullien                     Christopher Jullien   26  1993-03-22
# A. Rodríguez           Ángelo José Rodríguez Henry   30  1989-04-04
# ...                                            ...  ...         ...
# Zhang Wei                                       张威   19  2000-05-16
# I. Schubert-Abubakari   Ishamel Schubert-Abubakari   18  2000-08-17
# S. Erimuya                  Saturday Keigo Erimuya   21  1998-01-10
# D. Henry                              Doneil Henry   26  1993-04-20
# Lourency                     Lourency N. Rodrigues   23  1996-01-02
#
#                        height_cm  weight_kg     nationality  \
# short_name
# Kim Min Hyeok                187         73  Korea Republic
# L. Mai                       190         88         Germany
# T. Kainz                     174         70         Austria
# C. Jullien                   196         88          France
# A. Rodríguez                 181         80        Colombia
# ...                          ...        ...             ...
# Zhang Wei                    186         75        China PR
# I. Schubert-Abubakari        171         65         Germany
# S. Erimuya                   190         75         Nigeria
# D. Henry                     188         82          Canada
# Lourency                     174         74          Brazil
#
#                                          club
# short_name
# Kim Min Hyeok          Jeonbuk Hyundai Motors
# L. Mai                      Bayern München II
# T. Kainz                         TSV Hartberg
# C. Jullien                             Celtic
# A. Rodríguez              Minnesota United FC
# ...                                       ...
# Zhang Wei              Hebei China Fortune FC
# I. Schubert-Abubakari           Hallescher FC
# S. Erimuya                           Cádiz CF
# D. Henry               Vancouver Whitecaps FC
# Lourency                       Gil Vicente FC
#
# [3656 rows x 7 columns]

# %%
# upsample: increase the sampling rate -> frac>1 ('\"replace" parameter has to be True for frac parameter > 1)
df.sample(frac=2, replace=True)

#doubled original number of rows
# Out:
#                        long_name  age         dob  height_cm  weight_kg  \
# short_name
# R. Bertrand        Ryan Bertrand   29  1989-08-05        179         80
# J. Beauguel  Jean-David Beauguel   27  1992-03-21        196         98
# A. Balzano       Antonio Balzano   33  1986-06-13        174         74
# I. Quílez          Ismael Quílez   29  1989-11-16        171         75
# J. Harrop          Joshua Harrop   23  1995-12-15        175         70
# ...                          ...  ...         ...        ...        ...
# L. Perrin            Loïc Perrin   33  1985-08-07        181         80
# Pol García       Pol García Tena   24  1995-02-18        183         75
# B. Samba             Brice Samba   25  1994-04-25        186         79
# A. González     Alfonso González   24  1994-09-05        173         70
# O. Baumann        Oliver Baumann   29  1990-06-02        187         82
#
#             nationality                 club
# short_name
# R. Bertrand     England          Southampton
# J. Beauguel      France       Viktoria Plzeň
# A. Balzano        Italy              Pescara
# I. Quílez     Argentina      Central Córdoba
# J. Harrop       England    Preston North End
# ...                 ...                  ...
# L. Perrin        France     AS Saint-Étienne
# Pol García        Spain    Sint-Truidense VV
# B. Samba          Congo    Nottingham Forest
# A. González      Mexico            Monterrey
# O. Baumann      Germany  TSG 1899 Hoffenheim
#
# [36556 rows x 7 columns]

# %% [markdown]
# # 6 Filter a Dataframe: qeuery()

# %%
df = pd.read_csv('csv files/players_20.csv')
df.set_index('short_name', inplace=True)
df = df[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality","club"]]

# %%
# select players older than 34
df.query("age> 34")

#exercise: write the equivalent boolean slicing
df[df['age'] > 34].head()
# Out:
#                                     long_name  age         dob  height_cm  \
# short_name
# Z. Ibrahimović             Zlatan Ibrahimović   37  1981-10-03        195
# Pepe             Képler Laveran Lima Ferreira   36  1983-02-26        188
# G. Buffon                    Gianluigi Buffon   41  1978-01-28        192
# Casillas              Iker Casillas Fernández   38  1981-05-20        185
# F. Quagliarella            Fabio Quagliarella   36  1983-01-31        180
#
#                  weight_kg nationality       club
# short_name
# Z. Ibrahimović          95      Sweden  LA Galaxy
# Pepe                    81    Portugal   FC Porto
# G. Buffon               92       Italy   Juventus
# Casillas                84       Spain   FC Porto
# F. Quagliarella         79       Italy  Sampdoria

# %%
# select players older than 34 from Italy
df.query("age >34 and nationality =='Italy'")

#exercise: boolean slicing equivalent
df[(df['age'] > 34) & (df['nationality'] == 'Italy')].head()
# Out:
#                            long_name  age         dob  height_cm  weight_kg  \
# short_name
# G. Buffon           Gianluigi Buffon   41  1978-01-28        192         92
# F. Quagliarella   Fabio Quagliarella   36  1983-01-31        180         79
# D. De Rossi         Daniele De Rossi   35  1983-07-24        184         83
# A. Mirante           Antonio Mirante   35  1983-07-08        193         79
# A. Diamanti      Alessandro Diamanti   36  1983-05-02        180         75
#
#                 nationality               club
# short_name
# G. Buffon             Italy           Juventus
# F. Quagliarella       Italy          Sampdoria
# D. De Rossi           Italy       Boca Juniors
# A. Mirante            Italy               Roma
# A. Diamanti           Italy  Western United FC

# %%
# add a "not" operator to the first example
df.query("not(age> 34)").head()

#exercise: boolean slicing equivalent
df[~(df['age'] > 34)].head()
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# J. Oblak                 188         87    Slovenia      Atlético Madrid
# E. Hazard                175         74     Belgium          Real Madrid

# %%
# convert height to meters and select those with height above 1.8
df.query("height_cm/100 > 1.8").head()

#exercise: boolean slicing equivalent
df[(df['height_cm']/100 > 1.8)].head()
# Out:
#                                              long_name  age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# K. De Bruyne                           Kevin De Bruyne   28  1991-06-28
# M. ter Stegen                    Marc-André ter Stegen   27  1992-04-30
# V. van Dijk                            Virgil van Dijk   27  1991-07-08
#
#                    height_cm  weight_kg  nationality             club
# short_name
# Cristiano Ronaldo        187         83     Portugal         Juventus
# J. Oblak                 188         87     Slovenia  Atlético Madrid
# K. De Bruyne             181         70      Belgium  Manchester City
# M. ter Stegen            187         85      Germany     FC Barcelona
# V. van Dijk              193         92  Netherlands        Liverpool

# %%
df['dob'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df['dob'].dt.year
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\accessors.py:643, in CombinedDatetimelikeProperties.__new__(cls, data)
#     640 elif isinstance(data.dtype, PeriodDtype):
#     641     return PeriodProperties(data, orig)
# --> 643 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
# select players that were born after 1990

#check data type
df.dtypes
# convert "dob" column to datetime type
df["dob"] = df["dob"].astype("datetime64[ns]")
# query
df.query("dob.dt.year > 1990")

#exercise: boolean slicing equivalent
df[df['dob'].dt.year > 1990]

# %% [markdown]
# # 7 apply()

# %%
df = pd.read_csv('csv files/players_20.csv')
df.set_index('short_name', inplace=True)
df = df[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality","club"]]

# %%
'''
used to apply a function to a DataFrame or Series element-wise, row-wise, or column-wise.
'''

# use numpy function and apply it to series
df['age'].apply(np.sqrt)

# %%
# create your own function and apply it to a dataframe

def calculate_bmi(dataframe):
    return dataframe['weight_kg'] / (dataframe['height_cm']/100)**2

df.apply(calculate_bmi, axis=1)

# %% [markdown]
# # 8 Lambda function

# %% [raw]
# Useful for creating temporary functions (simple transformations, logic on the fly, etc.).

# %%
df = pd.read_csv('csv files/players_20.csv')
df.set_index('short_name', inplace=True)
df = df[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality","club"]]

# %% [markdown]
# ## 8.1 Basics

# %%
# basic function
def sum_values(a,b):
    return a+b

# %%
sum_values(2,3)

# %%
# lambda function (one liner)
'''
lambda input1,input2:output/operation
'''

sum_values_lambda = lambda a,b: a+b

# %%
sum_values_lambda(2,3)

# %% [markdown]
# ## 8.2 apply() + Lambda function

# %%
# use lambda function to convert "height_cm" series to meters
df['height_cm'].apply(lambda x: x/100)

#alternative
df['height_cm']/100

# %%
# use lambda to convert "long_name" series to upper case
df['long_name'].apply(lambda a: a.upper())

#alternative with str attribute
'''
cannot just do df['long_name'].upper() because df['long_name'] is a series 
and not a string unlike 'a' in lambda a: a.upper()
'''

df['long_name'].str.upper()

# %%
# use lambda to get the year or "dob" of series
df["dob"] = df["dob"].astype("datetime64[ns]")
df["dob"].apply(lambda x: x.year)

#alternative can be found in 6 Filter a Dataframe: qeuery()

# %%
# apply lambda function to a dataframe to calculate bmi
df.apply(lambda x:x['weight_kg']/(x['height_cm']/100)**2, axis=1)

# %% [markdown]
# # 9 Copy a Dataframe: copy()

# %%
df = pd.read_csv('csv files/players_20.csv')
df.set_index('short_name', inplace=True)
df = df[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality","club"]]

# %% [markdown]
# ## 9.1 deep = True

# %%
# deep=True by default 
# (modifications made to original dataframe will not be reflected in the coy and vice versa)
df_copy = df.copy()
df.loc["L. Messi", "height_cm"] = 190

# %%
df.head()
df_copy.head()

# %% [markdown]
# ## 9.2 deep = False

# %%
# any modifications made to the original dataframe will be reflected on the copy
df_copy = df.copy(deep=False)

# %%
df.loc["Cristiano Ronaldo", "height_cm"] = 200

# %%
df.head()
df_copy.head()

# %% [markdown]
# ## 9.3 Simple assignment (equivalent to deep=False)

# %%
# make a copy
df_new_copy = df

# %%
# update value in original datframe
df.loc["Neymar Jr", "height_cm"] = 190

# %%
df.head()
df_new_copy.head()
