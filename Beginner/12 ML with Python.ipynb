# %%
import pandas as pd
df = pd.read_csv('csv files/Boston House Prices.csv')
df
# Out:
#      Rooms  Distance  Value
# 0    6.575    4.0900   24.0
# 1    6.421    4.9671   21.6
# 2    7.185    4.9671   34.7
# 3    6.998    6.0622   33.4
# 4    7.147    6.0622   36.2
# ..     ...       ...    ...
# 501  6.593    2.4786   22.4
# 502  6.120    2.2875   20.6
# 503  6.976    2.1675   23.9
# 504  6.794    2.3889   22.0
# 505  6.030    2.5050   11.9
#
# [506 rows x 3 columns]

# %% [markdown]
# # 1 Linear Regression with Statsmodels

# %%
import statsmodels.api as sm

# %% [markdown]
# ## 1.1 Simple Linear Regression

# %% [markdown]
# ### 1.1.1 Define dependent and independent variable

# %%
# dependent varaible 
y = df['Value']

#independent varaible
x = df['Rooms']

# %% [markdown]
# ### 1.1.2 Exploring the dataset

# %%
df.plot(kind='scatter', x='Rooms', y='Value')
# Out:
# <Axes: xlabel='Rooms', ylabel='Value'>

# %% [markdown]
# ### 1.1.3. Making the regression: adding a constant and fitting the model

# %%
# adding a constant
x = sm.add_constant(x)

#fitting the model
lm = sm.OLS(y, x).fit()

# %%
#predict
lm.predict(x)
# Out:
# 0      25.175746
# 1      23.774021
# 2      30.728032
# 3      29.025938
# 4      30.382152
#          ...
# 501    25.339584
# 502    21.034286
# 503    28.825691
# 504    27.169108
# 505    20.215096
# Length: 506, dtype: float64

# %% [markdown]
# ### 1.1.4 Regression Table

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Value   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     471.8
# Date:                Tue, 05 Aug 2025   Prob (F-statistic):           2.49e-74
# Time:                        19:05:36   Log-Likelihood:                -1673.1
# No. Observations:                 506   AIC:                             3350.
# Df Residuals:                     504   BIC:                             3359.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6706      2.650    -13.084      0.000     -39.877     -29.465
# ...

# %% [markdown]
# ### 1.1.5 Linear Regression Equation

# %%
# Rooms Coeff: 9.1021
# Const. coeff.: -34.6706

# Linear equation : y = ax + b

y_pred = 9.1021*x['Rooms'] + -34.6706

# %% [markdown]
# ### 1.1.6 Plotting the regression line

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# plotting the data points
plt.figure(figsize = (10,5))
sns.scatterplot(x=x['Rooms'], y=y)

#plotting the line
sns.lineplot(x=x['Rooms'], y=y_pred, color='red')

#axes
plt.xlim(0)
plt.ylim(0)
plt.savefig('csv files/linear_regression')
plt.show()

# %% [markdown]
# # 2 Multiple Linear Regression

# %%
df = pd.read_csv('csv files/Boston House Prices.csv')

# %% [markdown]
# ## 2.1 Define dep. and indep. variables

# %%
# dependent varaible 
y = df['Value']

#independent varaible
x = df[['Rooms', 'Distance']]

# %% [markdown]
# ## 2.2 Making the regression: adding a constant and fitting the model

# %%
x = sm.add_constant(x) #add constant
lm = sm.OLS(y,x).fit() # fitting the model

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Value   R-squared:                       0.496
# Model:                            OLS   Adj. R-squared:                  0.494
# Method:                 Least Squares   F-statistic:                     247.0
# Date:                Tue, 05 Aug 2025   Prob (F-statistic):           1.84e-75
# Time:                        19:08:57   Log-Likelihood:                -1667.1
# No. Observations:                 506   AIC:                             3340.
# Df Residuals:                     503   BIC:                             3353.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6361      2.621    -13.212      0.000     -39.786     -29.486
# ...

# %% [markdown]
# # 3 Linear Regression with sklearn

# %%
df = pd.read_csv('csv files/Boston House Prices.csv')

# %%
from sklearn import linear_model

# %% [markdown]
# ## 3.1 Define the dep and indep variable

# %%
y = df['Value'] #dep var
x= df[['Rooms', 'Distance']] # indep var

# %% [markdown]
# ## 3.2 Fitting the model

# %%
# no need to add constant since sklearn automatically does it

lm = linear_model.LinearRegression()
lm.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## 3.3 Predicting values

# %%
lm.predict(x)
# Out:
# array([25.23262311, 24.30597474, 31.03025338, 29.9197274 , 31.23113776,
#        24.92052548, 20.99628003, 22.59515685, 17.89792552, 21.43016488,
#        24.59312806, 21.29554669, 19.86012857, 20.02480328, 21.19854962,
#        18.91052046, 19.79946305, 20.16587486, 15.24036623, 17.62554884,
#        16.24441157, 19.82577837, 21.36632302, 18.52848931, 19.65425152,
#        16.82067934, 18.81534563, 20.76312523, 24.70679323, 26.17680132,
#        17.71571146, 20.84706509, 19.68285587, 17.39216584, 20.85532906,
#        19.22540394, 18.42427779, 18.77543693, 19.75391977, 26.04958067,
#        29.82538634, 27.7461615 , 22.45651299, 22.82617229, 21.57637181,
#        17.86689491, 18.78224174, 21.21771802, 15.7523132 , 17.64542212,
#        21.17812468, 22.51593928, 26.00129836, 21.48617409, 20.7648873 ,
#        33.41670435, 26.03470634, 29.42393915, 23.26887906, 20.91861579,
#        19.42498135, 21.20638654, 25.71803969, 28.7805479 , 32.39778062,
# ...

# %% [markdown]
# ## 3.4 Regression table

# %%
# r2 value
lm.score(x,y)
# Out:
# 0.4955246476058477

# %%
# coefficient
lm.coef_
# Out:
# array([8.80141183, 0.48884854])

# %%
# intercept
lm.intercept_
# Out:
# -34.636050175473315
